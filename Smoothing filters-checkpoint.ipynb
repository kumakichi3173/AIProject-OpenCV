# %%
# This program smooths the image by convolving a kernel filter over the image. 
# There are various kernels used to smooth images such as Gaussian, Median, Normalized Box Filter, etc.
# We are testing to see the differences between each kernel filter and their effects on the image.
# 

# Importing modules
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2 # OpenCV
import glob # loading paths
from matplotlib.pyplot import figure

# load an image (in jpg)
images = glob.glob('*.jpg') #** means all the pictures of the array, and * means only 1 image

print(images)

print(type(images))
print(np.shape(images))
print(images[1])
# Out:
# ['gamma_adjusted.jpg', 'NightSightColor.jpg', 'rotated_image.jpg']
# <class 'list'>
# (3,)
# NightSightColor.jpg

# %%
# load as color image
# [0] is the aerial image in the array and [1] is the fracture_spine (MRI) image in the array
# see what pictures are in the array above result
img = cv2.imread(images[1], cv2.IMREAD_COLOR) 
print()

# %%
# displaying the title
figure(figsize=(10,10))

plt.title("Original Image")

plt.imshow(img)

# %%
# Applying Normalized Box Filter with a [3x3] matrix Kernel
img_blur = cv2.blur(img, (20, 20))

# Applying 10 convolutions to see more effect
for i in range(100):
    img_blur = cv2.blur(img, (3, 3))

figure(figsize=(10,10))

plt.title("Image Blur")

plt.imshow(img_blur)

print(img_blur.shape)
# Out:
# (1200, 1600, 3)

# %%
# display color and grayscale images
fig, axes = plt.subplots(1, 2, figsize=(20, 20), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].set_title("Original Image")
ax[0].imshow(img)

ax[1].set_title("Normalized Box Filter Image")
ax[1].imshow(img_blur, cmap=plt.cm.Greys_r, interpolation = "nearest")

for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()

# %%
#print(img.shape)

img_gaussian = cv2.GaussianBlur(img, (21,21),sigmaX=0)

figure(figsize=(10,10))

plt.title("Image Gaussian Blur")

plt.imshow(img_gaussian)

#print(img_gaussian.shape)

# %%
img_median = cv2.medianBlur(img, 11)

figure(figsize=(10,10))

plt.title("Image Median Blur")

plt.imshow(img_median)

# %%
# create figure
fig = plt.figure(figsize=(20, 20))
  
# setting values to rows and column variables
rows = 1
columns = 4

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
    
# showing image
plt.imshow(img)
plt.axis('off')
plt.title("Original")
    
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(img_blur)
plt.axis('off')
plt.title("Normalized Box")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
    
# showing image
plt.imshow(img_gaussian)
plt.axis('off')
plt.title("Gaussian")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
    
# showing image
plt.imshow(img_median)
plt.axis('off')
plt.title("Median")

# Tightness for the images
plt.tight_layout ()
plt.subplots_adjust(hspace=0, wspace=.1)
